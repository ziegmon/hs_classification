# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/anonymized_plm_and_d365_data.csv")

# %%
df
# Out:
#       division product_type material_type tariff_country_code  \
# 0          Men     T-Shirts       Knitted                DIST
# 1          Men     T-Shirts       Knitted                 JPN
# 2          Men     T-Shirts       Knitted                 CAN
# 3          Men     T-Shirts       Knitted                 BRA
# 4          Men     T-Shirts       Knitted                 CHE
# ...        ...          ...           ...                 ...
# 14898    Women       Shorts         Woven                 CHE
# 14899    Women       Shorts         Woven                 GBR
# 14900    Women       Shorts         Woven                  EU
# 14901    Women       Shorts         Woven                 CHN
# 14902    Women       Shorts         Woven                 JPN
#
#       tariff_country_description   tariff_code customs_description  \
# 0          Distributor countries        610910     knitted t-shirt
# 1                          Japan     610910010     knitted t-shirt
# ...

# %%
df = df.drop_duplicates(keep="first")
df.shape
# Out:
# (4295, 8)

# %%
df["material_type"].value_counts()
# Out:
# material_type
# Knit                       2179
# Woven                      1484
# Knitted                     483
# -                            72
# Laminated (WP Membrane)      48
# Laminated                    29
# Name: count, dtype: int64

# %%
df = df[df.product_type != "Jackets"]

# %%
df = df[df.material_type != "-"]

# %%
df.shape
# Out:
# (3694, 8)

# %%
df["product_type"].value_counts()
# Out:
# product_type
# T-Shirts                 855
# Tights                   479
# Shorts                   478
# Sweatshirts              422
# Pants                    413
# Short Sleeves            315
# Trousers                 118
# Bras                     113
# Tanks                    101
# Winter Jackets            96
# Hoodies & Sweatshirts     79
# Skirts                    65
# Long Sleeves              55
# Crop Tops                 55
# Vests                     19
# Dresses                   19
# Sweatpants                12
# Name: count, dtype: int64

# %%
df["material_type"] = df["material_type"].replace("Knit", "Knitted")

# %%
df["material_type"].value_counts()
# Out:
# material_type
# Knitted                    2634
# Woven                      1040
# Laminated (WP Membrane)      20
# Name: count, dtype: int64

# %%
condition1 = df['customs_description'].str.contains('woven', case=False) & (df['material_type'].str.lower() == 'knitted')
condition2 = df['customs_description'].str.contains('knitted', case=False) & (df['material_type'].str.lower() == 'woven')

exclude_mask = condition1
df = df[~exclude_mask]

# %%
df.shape
# Out:
# (3596, 8)

# %%
df = df[df["tariff_code"] != "6109901049"]

# %%
df.shape
# Out:
# (3590, 8)

# %%
df = df[df["material_composition"].notna()]

# %%
df.shape
# Out:
# (3435, 8)

# %%
df
# Out:
#       division product_type material_type tariff_country_code  \
# 0          Men     T-Shirts       Knitted                DIST
# 1          Men     T-Shirts       Knitted                 JPN
# 2          Men     T-Shirts       Knitted                 CAN
# 3          Men     T-Shirts       Knitted                 BRA
# 4          Men     T-Shirts       Knitted                 CHE
# ...        ...          ...           ...                 ...
# 14898    Women       Shorts         Woven                 CHE
# 14899    Women       Shorts         Woven                 GBR
# 14900    Women       Shorts         Woven                  EU
# 14901    Women       Shorts         Woven                 CHN
# 14902    Women       Shorts         Woven                 JPN
#
#       tariff_country_description   tariff_code customs_description  \
# 0          Distributor countries        610910     knitted t-shirt
# 1                          Japan     610910010     knitted t-shirt
# ...

# %%
df2 = df[(df["product_type"] == "T-Shirts") & (df["material_type"] == "Woven")]
df2
# Out:
#       division product_type material_type tariff_country_code  \
# 1064       Men     T-Shirts         Woven                  EU
# 1065       Men     T-Shirts         Woven                 GBR
# 1066       Men     T-Shirts         Woven                 JPN
# 1067       Men     T-Shirts         Woven                 NOR
# 1068       Men     T-Shirts         Woven                 AUS
# ...        ...          ...           ...                 ...
# 13026    Women     T-Shirts         Woven                 NOR
# 13027    Women     T-Shirts         Woven                 CAN
# 13028    Women     T-Shirts         Woven                 JPN
# 13029    Women     T-Shirts         Woven                 USA
# 13030    Women     T-Shirts         Woven                 GBR
#
#       tariff_country_description tariff_code customs_description  \
# 1064                      Europe  6109909000             t-shirt
# 1065              United Kingdom  6109909000             t-shirt
# ...

# %%
df.shape
# Out:
# (3435, 8)

# %%
df[(df["product_type"] == "Short Sleeves")]
# Out:
#      division   product_type material_type tariff_country_code  \
# 18        Men  Short Sleeves       Knitted                 GBR
# 19        Men  Short Sleeves       Knitted                 JPN
# 20        Men  Short Sleeves       Knitted                DIST
# 21        Men  Short Sleeves       Knitted                  EU
# 30        Men  Short Sleeves       Knitted                 CAN
# ...       ...            ...           ...                 ...
# 9752    Women  Short Sleeves       Knitted                 CHN
# 9753    Women  Short Sleeves       Knitted                 AUS
# 9754    Women  Short Sleeves       Knitted                 HKG
# 9755    Women  Short Sleeves       Knitted                 NOR
# 9756    Women  Short Sleeves       Knitted                 KOR
#
#      tariff_country_description tariff_code customs_description  \
# 18               United Kingdom  6109100010     knitted t-shirt
# 19                        Japan   610910010     knitted t-shirt
# ...

# %%
df = df.drop(df[(df["product_type"] == "T-Shirts") & (df["material_type"] == "Woven")].index)

# %%
df["tariff_code"].value_counts()
# Out:
# tariff_code
# 6109902000    104
# 61099010       91
# 6104630000     75
# 6109909000     65
# 6103430000     55
#              ...
# 6201407000      1
# 6110200012      1
# 6211431007      1
# 6109100021      1
# 6211430027      1
# Name: count, Length: 309, dtype: int64

# %%
condition = (df["division"] == "Women") & (df["tariff_code"] == "6109901090") & (df["customs_description"] == "Knitted Tank") |  (df["customs_description"] == "Knitted T-Shirt")
df.loc[condition, "tariff_code"] = "6109901050"

# %%
df["tariff_code"].value_counts()
# Out:
# tariff_code
# 6109902000    104
# 61099010       91
# 6104630000     75
# 6109909000     65
# 6103430000     55
#              ...
# 6201407000      1
# 6110200012      1
# 6211431007      1
# 6109100021      1
# 6211430027      1
# Name: count, Length: 309, dtype: int64

# %%
df.shape
# Out:
# (3339, 8)

# %%
mini_df_skor = pd.DataFrame(df[df['tariff_country_code'] == 'KOR'])
mini_df_hk = pd.DataFrame(df[df['tariff_country_code'] == 'HKG'])
mini_df_uk = pd.DataFrame(df[df['tariff_country_code'] == 'GBR'])
mini_df_jap = pd.DataFrame(df[df['tariff_country_code'] == 'JPN'])
mini_df_br = pd.DataFrame(df[df['tariff_country_code'] == 'BRA'])

# %%
mini_df_ch = pd.DataFrame(df[df['tariff_country_code'] == 'CHE'])

# %%
mini_df_can = pd.DataFrame(df[df['tariff_country_code'] == 'CAN'])

# %%
mini_df_can
# Out:
#       division   product_type material_type tariff_country_code  \
# 2          Men       T-Shirts       Knitted                 CAN
# 22         Men       T-Shirts       Knitted                 CAN
# 30         Men  Short Sleeves       Knitted                 CAN
# 85         Men       T-Shirts       Knitted                 CAN
# 125        Men  Short Sleeves       Knitted                 CAN
# ...        ...            ...           ...                 ...
# 14573    Women       T-Shirts       Knitted                 CAN
# 14687    Women    Sweatshirts       Knitted                 CAN
# 14788    Women    Sweatshirts         Woven                 CAN
# 14878    Women          Pants       Knitted                 CAN
# 14896    Women         Shorts         Woven                 CAN
#
#       tariff_country_description tariff_code customs_description  \
# 2                         Canada  6109100012     knitted t-shirt
# ...

# %%
mini_df_usa = pd.DataFrame(df[df['tariff_country_code'] == 'USA'])
mini_df_usa.shape
# Out:
# (242, 8)

# %%
prefixes_to_exclude = ["6201", "6202", "6203", "6204", "6210", "6211"]

# %%
mini_df_usa = mini_df_usa[~mini_df_usa["tariff_code"].astype(str).str.startswith(tuple(prefixes_to_exclude))]
words_to_exclude = "crop|tank"
mini_df_usa = mini_df_usa[~mini_df_usa["customs_description"].str.contains(words_to_exclude, case=False, na=False)]
mini_df_usa.shape
# Out:
# (150, 8)

# %%
mini_df_usa["customs_description"].value_counts()
# Out:
# customs_description
# knitted t-shirt                 60
# knitted tights                  20
# knitted pants                   13
# knitted hoodie                  10
# bra                              8
# knitted sweatshirt               8
# hoodie                           7
# knitted shorts                   5
# knitted joggers                  3
# tights                           3
# t-shirt                          3
# long sleeves top                 2
# knitted tights half              2
# knitted long sleeves t-shirt     1
# knitted tights short             1
# knitted singlet                  1
# knitted half tights              1
# knitted short tights             1
# knitted tights shorts            1
# Name: count, dtype: int64

# %%
prod_to_exclude = "sweatshirt|hoodie"
mini_df_usa = mini_df_usa[~mini_df_usa["customs_description"].str.contains(prod_to_exclude, case=False, na=False)]

# %%
mask = (
    mini_df_usa['product_type'].str.contains("Bras", case=False, na=False) &
    mini_df_usa['tariff_code'].astype(str).str.startswith("62")
)

mini_df_usa.loc[mask, 'product_type'] = mini_df_usa.loc[mask, 'product_type'].str.replace("knitted", "woven", case=True)
mini_df_usa.shape
# Out:
# (125, 8)

# %%
mini_df_usa["tariff_code"].value_counts()
# Out:
# tariff_code
# 6109901050    20
# 6109901007    18
# 6104632011    18
# 6103431520    16
# 6109100012    12
# 6109100040    10
# 6212109020     8
# 6104632030     7
# 6103431550     3
# 6103421020     2
# 6109100004     2
# 6109901090     2
# 6104622011     2
# 6110303010     1
# 6103421050     1
# 6109901065     1
# 6110303020     1
# 6104622030     1
# Name: count, dtype: int64

# %%
mask = (
    (mini_df_usa['division'].str.lower() == 'men') &
    (mini_df_usa['tariff_code'].astype(str) == "6109100040")
)

mini_df_usa.loc[mask, 'tariff_code'] = "6109100012"
mini_df_usa.shape
# Out:
# (125, 8)

# %%
mini_df_usa["tariff_code"].value_counts()
# Out:
# tariff_code
# 6109901050    20
# 6109901007    18
# 6104632011    18
# 6103431520    16
# 6109100012    13
# 6109100040     9
# 6212109020     8
# 6104632030     7
# 6103431550     3
# 6109100004     2
# 6103421020     2
# 6104622011     2
# 6109901090     2
# 6110303020     1
# 6109901065     1
# 6103421050     1
# 6110303010     1
# 6104622030     1
# Name: count, dtype: int64

# %%
mini_df_usa["material_type"].value_counts()
# Out:
# material_type
# Knitted    125
# Name: count, dtype: int64

# %%
mini_df_eu = pd.DataFrame(df[df['tariff_country_code'] == 'EU'])
mini_df_eu.shape
# Out:
# (247, 8)

# %%
mini_df_aus = pd.DataFrame(df[df['tariff_country_code'] == 'AUS'])
mini_df_aus.shape
# Out:
# (243, 8)

# %%
mini_df_aus["tariff_code"].value_counts()
# Out:
# tariff_code
# 6109900006    19
# 6109900005    18
# 6104630038    18
# 6203430004    17
# 6103430032    16
# 6110300052    13
# 6203430027    13
# 6204630004    13
# 6204630003    10
# 6109900037    10
# 6109100005    10
# 6109900028     9
# 6212100029     8
# 6109100006     8
# 6104630039     7
# 6114300006     6
# 6110200050     6
# 6201400004     5
# 6109100028     4
# 6110200052     4
# 6109100037     4
# 6103430044     4
# 6202400014     3
# 6110300057     2
# 6103420011     2
# 6204530011     2
# 6110300050     2
# 6114200006     2
# 6211339004     1
# 6103420015     1
# 6114200005     1
# 6104620011     1
# 6110300053     1
# 6204430017     1
# 6104620015     1
# 6211430027     1
# Name: count, dtype: int64

# %%
mask = (
    (mini_df_aus['product_type'].str.contains("Sweatshirt", case=False, na=False)) &
    (mini_df_aus['tariff_code'].astype(str) == "6110300052")
)

mini_df_aus.loc[mask, 'tariff_code'] = "6110300050"
mini_df_aus.shape
# Out:
# (243, 8)

# %%
mini_df_aus["tariff_code"].value_counts()
# Out:
# tariff_code
# 6109900006    19
# 6109900005    18
# 6104630038    18
# 6203430004    17
# 6103430032    16
# 6110300050    15
# 6203430027    13
# 6204630004    13
# 6204630003    10
# 6109900037    10
# 6109100005    10
# 6109900028     9
# 6212100029     8
# 6109100006     8
# 6104630039     7
# 6114300006     6
# 6110200050     6
# 6201400004     5
# 6103430044     4
# 6110200052     4
# 6109100037     4
# 6109100028     4
# 6202400014     3
# 6110300057     2
# 6103420011     2
# 6204530011     2
# 6114200006     2
# 6211339004     1
# 6103420015     1
# 6114200005     1
# 6104620011     1
# 6110300053     1
# 6204430017     1
# 6104620015     1
# 6211430027     1
# Name: count, dtype: int64

# %%
mini_df_aus
# Out:
#       division   product_type material_type tariff_country_code  \
# 9          Men       T-Shirts       Knitted                 AUS
# 26         Men       T-Shirts       Knitted                 AUS
# 44         Men  Short Sleeves       Knitted                 AUS
# 92         Men       T-Shirts       Knitted                 AUS
# 102        Men       T-Shirts       Knitted                 AUS
# ...        ...            ...           ...                 ...
# 14574    Women       T-Shirts       Knitted                 AUS
# 14683    Women    Sweatshirts       Knitted                 AUS
# 14797    Women    Sweatshirts         Woven                 AUS
# 14881    Women          Pants       Knitted                 AUS
# 14897    Women         Shorts         Woven                 AUS
#
#       tariff_country_description tariff_code customs_description  \
# 9                      Australia  6109100005     knitted t-shirt
# ...

# %%
mini_df_nor = pd.DataFrame(df[df['tariff_country_code'] == 'NOR'])
mini_df_nor.shape
# Out:
# (242, 8)

# %%
mini_df_nor
# Out:
#       division   product_type material_type tariff_country_code  \
# 12         Men       T-Shirts       Knitted                 NOR
# 16         Men       T-Shirts       Knitted                 NOR
# 42         Men  Short Sleeves       Knitted                 NOR
# 96         Men  Short Sleeves       Knitted                 NOR
# 99         Men       T-Shirts       Knitted                 NOR
# ...        ...            ...           ...                 ...
# 14575    Women       T-Shirts       Knitted                 NOR
# 14681    Women    Sweatshirts       Knitted                 NOR
# 14791    Women    Sweatshirts         Woven                 NOR
# 14880    Women          Pants       Knitted                 NOR
# 14891    Women         Shorts         Woven                 NOR
#
#       tariff_country_description tariff_code customs_description  \
# 12                        Norway    61091000     knitted t-shirt
# ...

# %%
mini_df_can["material_type"].value_counts()
# Out:
# material_type
# Knitted                    177
# Woven                       65
# Laminated (WP Membrane)      2
# Name: count, dtype: int64

# %%
mini_df_can
mini_df_can.shape
# Out:
# (244, 8)

# %%
countries_to_include = ['CAN', 'CHE']
mini_df_can_ch = pd.DataFrame(df[df['tariff_country_code'].isin(countries_to_include)])

# %%
countries_to_include = ['CAN', 'NOR']
mini_df_can_nor = pd.DataFrame(df[df['tariff_country_code'].isin(countries_to_include)])

# %%
countries_to_include = ['CAN', 'NOR']
mini_df_can_nor = pd.DataFrame(df[df['tariff_country_code'].isin(countries_to_include)])

# %%
mini_df_can_ch
# Out:
#       division   product_type material_type tariff_country_code  \
# 2          Men       T-Shirts       Knitted                 CAN
# 4          Men       T-Shirts       Knitted                 CHE
# 22         Men       T-Shirts       Knitted                 CAN
# 23         Men       T-Shirts       Knitted                 CHE
# 30         Men  Short Sleeves       Knitted                 CAN
# ...        ...            ...           ...                 ...
# 14788    Women    Sweatshirts         Woven                 CAN
# 14878    Women          Pants       Knitted                 CAN
# 14882    Women          Pants       Knitted                 CHE
# 14896    Women         Shorts         Woven                 CAN
# 14898    Women         Shorts         Woven                 CHE
#
#       tariff_country_description   tariff_code customs_description  \
# 2                         Canada    6109100012     knitted t-shirt
# ...

# %%
# mini_df_can.to_csv("datasets/test_df_can.csv")
# mini_df_ch.to_csv("datasets/test_df_ch.csv")
# mini_df_usa.to_csv("datasets/test_df_usa.csv")
# mini_df_can_ch.to_csv("datasets/test_df_can_ch.csv")
# mini_df_can_nor.to_csv("datasets/test_df_can_nor.csv")
# mini_df_nor.to_csv("datasets/test_df_nor.csv")
# mini_df_eu.to_csv("datasets/test_df_eu.csv")

# %%
mini_df_skor.to_csv("datasets/test_df_skor.csv")
mini_df_jap.to_csv("datasets/test_df_jap.csv")
mini_df_uk.to_csv("datasets/test_df_uk.csv")
mini_df_hk.to_csv("datasets/test_df_hk.csv")
mini_df_br.to_csv("datasets/test_df_br.csv")

# %%
mini_df_can_nor
# Out:
#       division   product_type material_type tariff_country_code  \
# 2          Men       T-Shirts       Knitted                 CAN
# 12         Men       T-Shirts       Knitted                 NOR
# 16         Men       T-Shirts       Knitted                 NOR
# 22         Men       T-Shirts       Knitted                 CAN
# 30         Men  Short Sleeves       Knitted                 CAN
# ...        ...            ...           ...                 ...
# 14791    Women    Sweatshirts         Woven                 NOR
# 14878    Women          Pants       Knitted                 CAN
# 14880    Women          Pants       Knitted                 NOR
# 14891    Women         Shorts         Woven                 NOR
# 14896    Women         Shorts         Woven                 CAN
#
#       tariff_country_description tariff_code customs_description  \
# 2                         Canada  6109100012     knitted t-shirt
# ...

# %%
historical_df = pd.read_csv("PLM_D365_merged_datasets_no_questionary.csv")

# %%
historical_df
# Out:
#       Unnamed: 0    item_code tariff_country_code tariff_country_description  \
# 0              0  1MD10480462                 CHE                Switzerland
# 1              1  1MD10480462                 CHN                      China
# 2              2  1MD10480462                 NZL                New Zealand
# 3              3  1MD10480462                 USA              United States
# 4              4  1MD10480462                 BRA                     Brazil
# ...          ...          ...                 ...                        ...
# 7456        7456  1WF10141573                 AUS                  Australia
# 7457        7457  1WF10141573                 CAN                     Canada
# 7458        7458  1WF10141573                 NOR                     Norway
# 7459        7459  1WF10141573                 BRA                     Brazil
# 7460        7460  1WF10141573                 JPN                      Japan
#
# ...

# %%
historical_df = historical_df.drop(columns=["Unnamed: 0"])

# %%
len(historical_df[(historical_df['tariff_country_description']=='Australia') & (historical_df['tariff_code']=='6110300052')])
# Out:
# 16

# %%
mask = (
    (historical_df['Product Type'].str.contains("Sweatshirt", case=False, na=False)) &
    (historical_df['tariff_code'].astype(str) == "6110300052") &
    (historical_df['tariff_country_description'].astype(str) == "Australia")
)

historical_df.loc[mask, 'tariff_code'] = "6110300050"
historical_df.shape
# Out:
# (7461, 26)

# %%
len(historical_df[(historical_df['tariff_country_description']=='Australia') & (historical_df['tariff_code']=='6110300052')])
# Out:
# 0

# %%
len(historical_df[(historical_df['tariff_country_description']=='United States') & (historical_df['tariff_code']=='6109100040')])
# Out:
# 27

# %%
mask = (
    (historical_df['Division'].str.lower() == 'men') &
    (historical_df['tariff_code'].astype(str) == "6109100040") &
    (historical_df['tariff_country_description'].astype(str) == "United States")
)

historical_df.loc[mask, 'tariff_code'] = "6109100012"
historical_df.shape
# Out:
# (7461, 26)

# %%
len(historical_df[(historical_df['tariff_country_description']=='United States') & (historical_df['tariff_code']=='6109100040')])
# Out:
# 25

# %%
historical_df
# Out:
#         item_code tariff_country_code tariff_country_description  \
# 0     1MD10480462                 CHE                Switzerland
# 1     1MD10480462                 CHN                      China
# 2     1MD10480462                 NZL                New Zealand
# 3     1MD10480462                 USA              United States
# 4     1MD10480462                 BRA                     Brazil
# ...           ...                 ...                        ...
# 7456  1WF10141573                 AUS                  Australia
# 7457  1WF10141573                 CAN                     Canada
# 7458  1WF10141573                 NOR                     Norway
# 7459  1WF10141573                 BRA                     Brazil
# 7460  1WF10141573                 JPN                      Japan
#
#        tariff_code customs_description                   material_composition  \
# 0     62113300-000          Woven Vest  100% Polyamide (Recycled Nylon) - rPA
# ...

# %%
historical_df.to_csv("PLM_D365_merged_datasets_no_questionary.csv")

# %%
test_df = pd.read_csv("../flask_app/all_bulk_results.csv")

# %%
test_df
# Out:
#       idx                                product_description  \
# 0      50  Product for CANADA: Men's woven shorts Shorts ...
# 1      51  Product for CANADA: Men's hoodie Sweatshirts M...
# 2      52  Product for CANADA: Men's hoodie Hoodies & Swe...
# 3      53  Product for CANADA: Men's knitted pants Pants ...
# 4      54  Product for CANADA: Men's knitted t-shirt T-Sh...
# ...   ...                                                ...
# 3016   15  Product for UNITED STATES: Men's knitted tank ...
# 3017   16  Product for UNITED STATES: Men's knitted tight...
# 3018   17  Product for UNITED STATES: Men's knitted t-shi...
# 3019   18  Product for UNITED STATES: Men's knitted t-shi...
# 3020   19  Product for UNITED STATES: Men's knitted tight...
#
#                       input_product  \
# 0               woven shorts Shorts
# 1                hoodie Sweatshirts
# 2      hoodie Hoodies & Sweatshirts
# 3               knitted pants Pants
# 4          knitted t-shirt T-Shirts
# ...
